# %%
import pandas as pd
import numpy as np
import os
import json

# %%
df_l = []

# %%
for file_name in os.listdir('./processed_data/matches/'):
    with open(os.path.join('./processed_data/matches/', file_name)) as f:
        s = json.load(f)
        df_l.append(s)

# %%
df = pd.DataFrame.from_records(df_l)

# %%
df.head()
# Out:
#              city        date dl_applied eliminator  overs player_of_match  \
# 0      Chandigarh  2008-05-03                           20       IK Pathan
# 1           Delhi  2018-04-27                           20         SS Iyer
# 2  Port Elizabeth  2009-05-10                           20       JP Duminy
# 3      Chandigarh  2019-04-01                           20       SM Curran
# 4          Jaipur  2019-04-20                           20       SPD Smith
#
#   result  season                        team1                  team2  \
# 0           2008              Kings XI Punjab  Kolkata Knight Riders
# 1           2018             Delhi Daredevils  Kolkata Knight Riders
# 2           2009  Royal Challengers Bangalore         Mumbai Indians
# 3           2019              Kings XI Punjab         Delhi Capitals
# 4           2019             Rajasthan Royals         Mumbai Indians
#
#   toss_decision            toss_winner        umpire1       umpire2 umpire3  \
# ...

# %%
df.to_csv('matches.csv', index=False)

# %%
matches=pd.read_csv('matches.csv')
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746 entries, 0 to 745
# Data columns (total 19 columns):
# city               733 non-null object
# date               746 non-null object
# dl_applied         19 non-null object
# eliminator         8 non-null object
# overs              746 non-null int64
# player_of_match    742 non-null object
# result             12 non-null object
# season             746 non-null int64
# team1              746 non-null object
# team2              746 non-null object
# toss_decision      746 non-null object
# toss_winner        746 non-null object
# umpire1            745 non-null object
# umpire2            745 non-null object
# umpire3            2 non-null object
# venue              746 non-null object
# win_by_runs        336 non-null float64
# win_by_wickets     398 non-null float64
# winner             734 non-null object
# dtypes: float64(2), int64(2), object(15)
# memory usage: 110.8+ KB

# %%
matches[pd.isnull(matches['winner'])]
matches['winner'].fillna('Draw', inplace=True)
matches.head()
# Out:
#              city        date dl_applied eliminator  overs player_of_match  \
# 0      Chandigarh  2008-05-03        NaN        NaN     20       IK Pathan
# 1           Delhi  2018-04-27        NaN        NaN     20         SS Iyer
# 2  Port Elizabeth  2009-05-10        NaN        NaN     20       JP Duminy
# 3      Chandigarh  2019-04-01        NaN        NaN     20       SM Curran
# 4          Jaipur  2019-04-20        NaN        NaN     20       SPD Smith
#
#   result  season                        team1                  team2  \
# 0    NaN    2008              Kings XI Punjab  Kolkata Knight Riders
# 1    NaN    2018             Delhi Daredevils  Kolkata Knight Riders
# 2    NaN    2009  Royal Challengers Bangalore         Mumbai Indians
# 3    NaN    2019              Kings XI Punjab         Delhi Capitals
# 4    NaN    2019             Rajasthan Royals         Mumbai Indians
#
#   toss_decision            toss_winner        umpire1       umpire2 umpire3  \
# ...

# %%
df = pd.DataFrame(matches)

# %%
len(df)
# Out:
# 746

# %%
matches.replace(['Mumbai Indians','Kolkata Knight Riders','Royal Challengers Bangalore','Deccan Chargers','Chennai Super Kings',
                 'Rajasthan Royals','Delhi Daredevils','Gujarat Lions','Kings XI Punjab',
                 'Sunrisers Hyderabad','Rising Pune Supergiants','Rising Pune Supergiant','Kochi Tuskers Kerala','Pune Warriors','Delhi Capitals']
                ,['MI','KKR','RCB','DC','CSK','RR','DD','GL','KXIP','SRH','RPS','RPS','KTK','PW','DCA'],inplace=True)

encode = {'team1': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13,'DCA':14},
          'team2': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13,'DCA':14},
          'toss_winner': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13,'DCA':14},
          'winner': {'MI':1,'KKR':2,'RCB':3,'DC':4,'CSK':5,'RR':6,'DD':7,'GL':8,'KXIP':9,'SRH':10,'RPS':11,'KTK':12,'PW':13,'DCA':14,'Draw':15}}
matches.replace(encode, inplace=True)
matches.head()
# Out:
#              city        date dl_applied eliminator  overs player_of_match  \
# 0      Chandigarh  2008-05-03        NaN        NaN     20       IK Pathan
# 1           Delhi  2018-04-27        NaN        NaN     20         SS Iyer
# 2  Port Elizabeth  2009-05-10        NaN        NaN     20       JP Duminy
# 3      Chandigarh  2019-04-01        NaN        NaN     20       SM Curran
# 4          Jaipur  2019-04-20        NaN        NaN     20       SPD Smith
#
#   result  season  team1  team2 toss_decision  toss_winner        umpire1  \
# 0    NaN    2008      9      2           bat            9      DJ Harper
# 1    NaN    2018      7      2         field            2  C Shamshuddin
# 2    NaN    2009      3      1           bat            1    BR Doctrove
# 3    NaN    2019      9     14         field           14    CB Gaffaney
# 4    NaN    2019      6      1         field            6       YC Barde
#
# ...

# %%
df1 = pd.DataFrame(matches)
df1
# Out:
#                city        date dl_applied eliminator  overs player_of_match  \
# 0        Chandigarh  2008-05-03        NaN        NaN     20       IK Pathan
# 1             Delhi  2018-04-27        NaN        NaN     20         SS Iyer
# 2    Port Elizabeth  2009-05-10        NaN        NaN     20       JP Duminy
# 3        Chandigarh  2019-04-01        NaN        NaN     20       SM Curran
# 4            Jaipur  2019-04-20        NaN        NaN     20       SPD Smith
# 5             Delhi  2018-04-23        NaN        NaN     20      AS Rajpoot
# 6      Johannesburg  2009-05-16        NaN        NaN     20       RG Sharma
# 7       East London  2009-05-01        NaN        NaN     20       JP Duminy
# 8            Jaipur  2010-04-11        NaN        NaN     20    SR Tendulkar
# 9            Jaipur  2019-04-11        NaN        NaN     20        MS Dhoni
# 10        Hyderabad  2016-04-30        NaN        NaN     20       DA Warner
# ...

# %%
dicVal = encode['winner']
temp1=df1['toss_winner'].value_counts(sort=True)
temp2=df1['winner'].value_counts(sort=True)
print('No of toss winners by each team')
for idx, val in temp1.iteritems():
   print('{} -> {}'.format(list(dicVal.keys())[list(dicVal.values()).index(idx)],val))
# Out:
# No of toss winners by each team
# MI -> 95
# KKR -> 91
# CSK -> 87
# KXIP -> 80
# DD -> 80
# RCB -> 80
# RR -> 79
# SRH -> 46
# DC -> 43
# PW -> 20
# GL -> 15
# RPS -> 13
# DCA -> 9
# KTK -> 8

# %%
print('No of match winners by each team')
for idx, val in temp2.iteritems():
   print('{} -> {}'.format(list(dicVal.keys())[list(dicVal.values()).index(idx)],val))
# Out:
# No of match winners by each team
# MI -> 104
# CSK -> 99
# KKR -> 91
# RCB -> 82
# KXIP -> 79
# RR -> 73
# DD -> 67
# SRH -> 57
# DC -> 29
# DCA -> 19
# RPS -> 15
# GL -> 13
# PW -> 12
# KTK -> 6

# %%
df3 = df1[['team1','team2']]
df3
# Out:
#      team1  team2
# 0        9      2
# 1        7      2
# 2        3      1
# 3        9     14
# 4        6      1
# 5        7      9
# 6        4      2
# 7        2      1
# 8        6      1
# 9        6      5
# 10      10      3
# 11       3      4
# 12      11      9
# 13       7      3
# 14       8     10
# 15       7      9
# 16       4      3
# 17       7      9
# 18       5      3
# 19       1      3
# 20       1      7
# 21      13      5
# 22       5      9
# 23       7      6
# 24       7      9
# 25      13     12
# 26      11     10
# 27       2     14
# 28       2      1
# 29       7      1
# ..     ...    ...
# 716      7      5
# 717     10      7
# 718      4      5
# 719      2      1
# 720     10     11
# 721      9      5
# 722     13      9
# 723      9      3
# 724      4      7
# 725     10      3
# 726      2      9
# 727     10      9
# 728      3      7
# 729     10      8
# 730      8      7
# 731     12      7
# 732      7      3
# 733      2      5
# ...

# %%
df4 = df1['winner']
df4
# Out:
# 0       9
# 1       7
# 2       1
# 3       9
# 4       6
# 5       9
# 6       4
# 7       1
# 8       1
# 9       5
# 10     10
# 11      3
# 12     11
# 13      3
# 14     10
# 15      7
# 16      4
# 17      7
# 18      5
# 19      1
# 20      7
# 21      5
# 22      5
# 23      7
# 24      7
# 25     13
# 26     11
# 27     14
# 28      1
# 29      7
#        ..
# 716     7
# 717    10
# 718     5
# 719     2
# 720    11
# 721     5
# 722    13
# 723     9
# 724     7
# 725    14
# 726     9
# 727     9
# 728    14
# 729    10
# 730     7
# 731     7
# 732     3
# 733     2
# 734     7
# 735     9
# 736     6
# 737     1
# 738    14
# 739     9
# 740     5
# 741     3
# 742     5
# 743     9
# 744     2
# 745     1
# Name: winner, Length: 746, dtype: int64

# %%
df5 = df3[~df3.isin(df4)]
df5
# Out:
#      team1  team2
# 0      NaN    2.0
# 1      NaN    2.0
# 2      3.0    NaN
# 3      NaN   14.0
# 4      NaN    1.0
# 5      7.0    NaN
# 6      NaN    2.0
# 7      2.0    NaN
# 8      6.0    NaN
# 9      6.0    NaN
# 10     NaN    3.0
# 11     NaN    4.0
# 12     NaN    9.0
# 13     7.0    NaN
# 14     8.0    NaN
# 15     NaN    9.0
# 16     NaN    3.0
# 17     NaN    9.0
# 18     NaN    3.0
# 19     NaN    3.0
# 20     1.0    NaN
# 21    13.0    NaN
# 22     NaN    9.0
# 23     NaN    6.0
# 24     NaN    9.0
# 25     NaN   12.0
# 26     NaN   10.0
# 27     2.0    NaN
# 28     2.0    NaN
# 29     NaN    1.0
# ..     ...    ...
# 716    NaN    5.0
# 717    NaN    7.0
# 718    4.0    NaN
# 719    NaN    1.0
# 720   10.0    NaN
# 721    9.0    NaN
# 722    NaN    9.0
# 723    NaN    3.0
# 724    4.0    NaN
# 725   10.0    3.0
# 726    2.0    NaN
# 727   10.0    NaN
# 728    3.0    7.0
# 729    NaN    8.0
# 730    8.0    NaN
# 731   12.0    NaN
# 732    7.0    NaN
# 733    NaN    5.0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-bce021ef6b6b> in <module>
# ----> 1 pd.concat(df5['team1'],df5['team2'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     239             raise TypeError('first argument must be an iterable of pandas '
# ...
